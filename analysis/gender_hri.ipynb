# %%
import numpy as np

from scipy.stats import ttest_ind
import matplotlib.pyplot as plt


group1 = np.array([p1, p5, p6])

#group2 = np.random.normal(p2, p3, p4)
group2 = np.array([p2, p3, p4])

# perform t-test
stat, p = ttest_ind(group1, group2)

# plot the results
plt.bar(['female', 'male'], [np.mean(group1), np.mean(group2)])
plt.errorbar(['female', 'male'], [np.mean(group1), np.mean(group2)], yerr=[np.std(group1), np.std(group2)], fmt='o', capsize=5)
plt.title(f"t-test result: t = {stat:.2f}, p = {p:.10f}")
plt.ylabel('Mean value')
plt.show()


filename = "my_plot.png"

# save the plot as a file
plt.savefig(filename)

# %%
group2
# Out:
# array([1165, 1368,  972])

# %%
np.mean(group2)  #male
# Out:
# 1168.3333333333333

# %%
np.mean(group1)  #female
# Out:
# 1100.3333333333333

# %%
p1=746.7736735343933+216.7549650669098+158+89.39406514167786+203.8116533756256+96.25647926330566 
p1=int(p1)
p2=538.4643979072571+135.8717861175537+180.72005605697632+81.7444577217102+176.78321361541748+51.85513353347778
p3=146.0481526851654+103.48677134513855+694.2552571296692+211.9985547065735+150.23995113372803+62.814157247543335
p4=309.33359003067017+63.37547183036804+215.02283239364624+39.599265336990356+232.45007276535034+112.80052399635315
p5=308.27549600601196+37.1833975315094+204.41755557060242+76.63992428779602+316.2131495475769+169.75160837173462
p6=165.6835000514984+64.0803427696228+212.08197259902954+94.83341836929321+91.26385307312012+51.32808327674866
p2=int(p2)
p3=int(p3)
p4=int(p4)
p5=int(p5)
p6=int(p6)
arr =np.array([p1, p2, p3, p4, p5, p6])
print(arr)
# Out:
# [1510 1165 1368  972 1112  679]

# %%
p1 #Female
p2 #Male
p3 #Male
p4 #Male
p5 #Female
p6 #Female
# Out:
# 1510.9908363819122

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# Generate two random samples
#np.random.seed(0)


#sample1 = np.random.normal(p1, p5, p6)
sample1=np.array([p1, p5, p6])
sample2=np.array([p2, p3, p4])
#sample2 = np.random.normal(p2, p3, p4)

# Perform two-sample t-test
t, p = stats.ttest_ind(sample1, sample2)

# Create a boxplot of the two samples
data = [sample1, sample2]
fig, ax = plt.subplots()
ax.boxplot(data)
ax.set_xticklabels(['Female', 'Male'])
ax.set_ylabel('Value')

# Add title and statistical information
ax.set_title('Two-sample t-test\np-value: {:.10f}'.format(p))

# Show the plot
plt.show()

# %%
t, p = ttest_ind(sample1, sample2)

# print the results
print('t =', t)
print('p =', p)
# Out:
# t = -0.2558279840534615
# p = 0.8107009997129297

# %%
sample1
# Out:
# array([1510, 1112,  679])
